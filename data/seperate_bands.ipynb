# %%
from sef import read 
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
# so we have a sampling rate of 1000
# If you just want to know what EEG state the person is in, you could use np.max instead of np.mean. 
# Then whichever band has the max will tell you about the person's state.

fs = 1000                               # Sampling rate (1000 Hz)

def get_eeg_bands(channel_data, display=False):
    band_to_data = {}
    # Get real amplitudes of FFT (only in postive frequencies)
    fft_vals = np.absolute(np.fft.rfft(channel_data))

    # Get frequencies for amplitudes in Hz
    fft_freq = np.fft.rfftfreq(len(channel_data), 1.0/fs)

    # Define EEG bands
    eeg_bands = {'Delta': (0, 4),
                 'Theta': (4, 8),
                 'Alpha': (8, 12),
                 'Beta': (12, 30),
                 'Gamma': (30, 45)}

    my_colors = ["g", "b","r","y","k"]

    # Take the mean of the fft amplitude for each EEG band
    eeg_band_fft = dict()
    for band in eeg_bands:  
        freq_ix = np.where((fft_freq >= eeg_bands[band][0]) & 
                           (fft_freq <= eeg_bands[band][1]))[0]
        eeg_band_fft[band] = np.mean(fft_vals[freq_ix])
        band_to_data[band] = channel_data[freq_ix]
    
    if display:
        # Plot the data (using pandas here cause it's easy)
        df = pd.DataFrame(columns=['band', 'val'])
        df['band'] = eeg_bands.keys()
        df['val'] = [eeg_band_fft[band] for band in eeg_bands]
        ax = df.plot.bar(x='band', y='val', legend=False, color=my_colors)
        ax.set_xlabel("EEG band")
        ax.set_ylabel("Mean band Amplitude")
    
    return band_to_data


def get_lengths(channel_to_bands):
    return {x:len(channel_to_bands[x]) for x in channel_to_bands}

def get_bands_to_matrix(sample_data):
    data = np.array(sample_data)
    #print(data.shape)

    # should split the sef of the samples to the bands 
    band_lengths = {}
    bands_to_matrix = {}

    for channel_index in range(data.shape[1]):
        band_to_data = get_eeg_bands(data[:,channel_index])
        band_lengths = get_lengths(band_to_data)
        for band in band_to_data:
            channel_data = np.array(band_to_data[band])
            channel_data = np.reshape(channel_data, (channel_data.shape[0],-1))

            if band not in bands_to_matrix:
                bands_to_matrix[band] = channel_data
            else:
                bands_to_matrix[band] = np.append(bands_to_matrix[band], channel_data, axis=1)

#     for band in bands_to_matrix:
#         print(bands_to_matrix[band].shape)
    return bands_to_matrix, band_lengths

# %%
import os

pd_dir = "D:/pd_data/band1_35Hz_PD_EC"
hc_dir = "D:/pd_data/band1_35Hz_HC_EC"

pd_files = [os.path.join(pd_dir,x) for x in os.listdir(pd_dir) if ".sef" == os.path.splitext(x)[1]]
hc_files = [os.path.join(hc_dir,x) for x in os.listdir(hc_dir) if ".sef" == os.path.splitext(x)[1]]

print(len(pd_files))
print(len(hc_files))
# Out:
# 44
# 24

# %%
band_to_lengths = {}
band_to_matricies = {}

def create_comb(files, band_to_lengths, band_to_matrices):
    for filepath in files:
        print(filepath)
        sample_data = read(filepath)[2]
        bands_to_matrix, band_lengths = get_bands_to_matrix(sample_data)
        for band in band_lengths:
            if band not in band_to_lengths:
                band_to_lengths[band] = [band_lengths[band]]
                band_to_matricies[band] = bands_to_matrix[band]
            else:
                band_to_lengths[band].append(band_lengths[band])
                #print(band_to_matrices[band].shape)
                #print(bands_to_matrix[band].shape
                # add the columns
                band_to_matrices[band] = np.append(band_to_matrices[band], bands_to_matrix[band], axis=0)
                
create_comb(pd_files, band_to_lengths, band_to_matricies)
create_comb(hc_files, band_to_lengths, band_to_matricies)
# Out:
# D:/pd_data/band1_35Hz_PD_EC\EC_CT001_20110526_1514_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT002_20110531_1431_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT003_20110607_1528_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT007_20110705_1523_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT013_20111019_1405_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT014_20111114_1411_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT015_20111118_1418_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT016_20111116_1422_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT017_20120104_1234_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT018_20120109_1431_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT019_20120112_1352_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT022_20120131_1421_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT024_20120214_1412_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT025_20120208_1419_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT026_20120213_1359_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT027_20120312_1358_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT028_20120313_1412_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT029_20120319_1406_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT030_20120507_1405_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT031_20120514_1409_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT032_20120604_1418_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT035_20120614_1400_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT036_20120626_1423_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT038_20120717_1416_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT039_20120713_1354_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT040_20120709_1419_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT041_20120723_1417_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT042_20120912_1416_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT043_20120806_1406_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT044_20120817_1336_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT046_20120823_1411_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT047_20121004_1405_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT048_20121015_1350_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT049_20121026_1437_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT050_20121101_1353_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT051_20121129_1408_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT052_20121205_1423_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT054_20130125_1421_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT056_20130130_1425_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT057_20130204_1444_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT058_20130205_1434_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT059_20130206_1429_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT060_20130312_1437_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_PD_EC\EC_CT061_20130321_1425_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT063_20130426_1337_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT065_20130624_1444_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT068_20130704_1417_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT071_20130813_1424_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT075_20160317_1435_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT076_20160331_1350_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT077_20160523_1416_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT078_20160421_1420_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT079_20160311_1428_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT080_20160513_1420_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT081_20160407_1435_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT083_20160512_1427_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT084_20160621_1422_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT085_20160707_022511_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT086_20160519_1359_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT087_20160623_1337_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT088_20160620_1428_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT089_20160819_021956_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT090_20160711_022219_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT091_20160812_021659_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT092_20160811_023329_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT095_20160729_023048_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT096_20160902_021953_Stitch_band_1_35.sef
# D:/pd_data/band1_35Hz_HC_EC\EC_CT097_20160908_021612_Stitch_band_1_35.sef
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-ddc40a257842> in <module>()
#      20 create_comb(pd_files, band_to_lengths, band_to_matricies)
#      21 create_comb(hc_files, band_to_lengths, band_to_matricies)
# ---> 22 print(len(band_to_lengths['theta']))
#
# KeyError: 'theta'

# %%
from sef_eeg_microstates import *
import time 

start = time.time()
print band_to_lengths.keys()
print(band_to_matricies['Theta'].shape)

def generate_microstates(band_to_matrices):
    for band in band_to_matricies:
        print band
        data = band_to_matricies[band]
        print("%d MB" % (data.size * data.itemsize/1024/1024))
        
        # we need to get the 213 channels representing the 213 channels in y-axis
        from preprocessing import chan_ID_213 as chs
        n_maps = 4 # the number of classes 
        mode = ["aahc", "kmeans", "kmedoids", "pca", "ica"][1]
        print("Clustering algorithm: {:s}".format(mode))
        locs = []
        maps, microstates, gfp_peaks, gev = clustering(data, fs, chs, locs, mode, n_maps, doplot=False)
        print("The length of the sequence: {0}".format(len(microstates)))
        print("The number of peaks: {0}".format(len(gfp_peaks)))
        
        # save the peaks and the sequences 
        np.save("microstates_{0}_4".format(band), microstates)
        np.save("peaks_{0}_4".format(band), gfp_peaks)
        
        # need to save the 
generate_microstates(band_to_matricies)
print("Total time: {0}".format(time.time()-start))
# Out:
# ['Theta', 'Beta', 'Delta', 'Gamma', 'Alpha']
# (48404L, 213L)
# Theta
# 78 MB
# Clustering algorithm: kmeans
# 	[+] Data format for clustering [GFP peaks, channels]: 1401 x 213
#
# 	[+] Clustering algorithm: mod. K-MEANS.
# The number of peaks: 1401
# 		K-means run 1/5 converged after 31 iterations.
# 		K-means run 2/5 converged after 14 iterations.
# 		K-means run 3/5 converged after 29 iterations.
# 		K-means run 4/5 converged after 17 iterations.
# 		K-means run 5/5 converged after 14 iterations.
#
#
#
# (48404L, 213L)
# (4L, 213L)
#
#
#
# 	[+] Computation time: 37.85
#
# 	[+] Global explained variance GEV = 0.593
# 		GEV_0: 0.090
# 		GEV_1: 0.212
# 		GEV_2: 0.099
# 		GEV_3: 0.192
# The length of the sequence: 48404
# The number of peaks: 1401
# Beta
# 353 MB
# Clustering algorithm: kmeans
# 	[+] Data format for clustering [GFP peaks, channels]: 6203 x 213
#
# 	[+] Clustering algorithm: mod. K-MEANS.
# The number of peaks: 6203
# 		K-means run 1/5 converged after 46 iterations.
# 		K-means run 2/5 converged after 37 iterations.
# 		K-means run 3/5 converged after 75 iterations.
# 		K-means run 4/5 converged after 28 iterations.
# 		K-means run 5/5 converged after 38 iterations.
#
#
#
# (217750L, 213L)
# (4L, 213L)
#
#
#
# 	[+] Computation time: 90.60
#
# 	[+] Global explained variance GEV = 0.616
# 		GEV_0: 0.196
# 		GEV_1: 0.106
# 		GEV_2: 0.232
# 		GEV_3: 0.082
# The length of the sequence: 217750
# The number of peaks: 6203
# Delta
# 78 MB
# Clustering algorithm: kmeans
# 	[+] Data format for clustering [GFP peaks, channels]: 1388 x 213
#
# 	[+] Clustering algorithm: mod. K-MEANS.
# The number of peaks: 1388
# 		K-means run 1/5 converged after 16 iterations.
# 		K-means run 2/5 converged after 13 iterations.
# 		K-means run 3/5 converged after 10 iterations.
# 		K-means run 4/5 converged after 12 iterations.
# 		K-means run 5/5 converged after 12 iterations.
#
#
#
# (48404L, 213L)
# (4L, 213L)
#
#
#
# 	[+] Computation time: 23.12
#
# 	[+] Global explained variance GEV = 0.592
# 		GEV_0: 0.080
# 		GEV_1: 0.175
# 		GEV_2: 0.134
# 		GEV_3: 0.204
# The length of the sequence: 48404
# The number of peaks: 1388
# Gamma
# 294 MB
# Clustering algorithm: kmeans
# 	[+] Data format for clustering [GFP peaks, channels]: 5195 x 213
#
# 	[+] Clustering algorithm: mod. K-MEANS.
# The number of peaks: 5195
# 		K-means run 1/5 converged after 39 iterations.
# 		K-means run 2/5 converged after 23 iterations.
# 		K-means run 3/5 converged after 24 iterations.
# 		K-means run 4/5 converged after 130 iterations.
# 		K-means run 5/5 converged after 65 iterations.
#
#
#
# (181382L, 213L)
# (4L, 213L)
#
#
#
# 	[+] Computation time: 110.20
#
# 	[+] Global explained variance GEV = 0.603
# 		GEV_0: 0.210
# 		GEV_1: 0.127
# 		GEV_2: 0.171
# 		GEV_3: 0.094
# The length of the sequence: 181382
# The number of peaks: 5195
# Alpha
# 78 MB
# Clustering algorithm: kmeans
# 	[+] Data format for clustering [GFP peaks, channels]: 1366 x 213
#
# 	[+] Clustering algorithm: mod. K-MEANS.
# The number of peaks: 1366
# 		K-means run 1/5 converged after 18 iterations.
# 		K-means run 2/5 converged after 12 iterations.
# 		K-means run 3/5 converged after 31 iterations.
# 		K-means run 4/5 converged after 40 iterations.
# 		K-means run 5/5 converged after 24 iterations.
#
#
#
# (48336L, 213L)
# (4L, 213L)
#
#
#
# 	[+] Computation time: 45.19
#
# 	[+] Global explained variance GEV = 0.639
# 		GEV_0: 0.099
# 		GEV_1: 0.090
# 		GEV_2: 0.314
# 		GEV_3: 0.136
# The length of the sequence: 48336
# The number of peaks: 1366
# Total time: 309.677999973

# %%
# get the total lengths as objects 
print band_to_lengths
# Out:
# {'Theta': [712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 706, 712, 712, 712, 712, 712, 712, 706, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712], 'Beta': [3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3176, 3203, 3203, 3203, 3203, 3203, 3203, 3176, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203, 3203], 'Delta': [712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 706, 712, 712, 712, 712, 712, 712, 706, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712, 712], 'Gamma': [2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2647, 2668, 2668, 2668, 2668, 2668, 2668, 2647, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668, 2668], 'Alpha': [711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 705, 711, 711, 711, 711, 711, 711, 705, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711, 711]}
